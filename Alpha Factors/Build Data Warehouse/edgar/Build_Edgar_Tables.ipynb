# %%
import pandas as pd

# %%
files = ['pre','num','sub','tag']
catalog = 'operations'
schema = 'finance_staging'

for file in files:
    filing = pd.read_csv(f"/Volumes/operations/finance/data/{file}.txt",sep='\t', low_memory=False, keep_default_na=False)
    filing = spark.createDataFrame(filing)
    filing.write.mode("overwrite").saveAsTable(f'{catalog}.{schema}.raw_filing_{file}_tbl')

# %%
filingsQ1 = pd.read_csv("/Volumes/operations/finance/data/num.txt", sep='\t', low_memory=False, keep_default_na=False)

# %%
spark.createDataFrame(filingsQ1).createOrReplaceTempView('df')
