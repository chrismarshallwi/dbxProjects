# %%
catalog = 'operations'
schema = 'finance_staging'
table_name = 'fact_staging_balance_sheet_tbl'

# %%
with open("sql/fact_staging_balance_sheet_tbl.sql", "r") as file:
    qry = file.read()
(
    spark.sql(qry)
    .write
    .format("delta")
    .mode("overwrite")
    .option("overwriteSchema", "true")
    .saveAsTable(f"{catalog}.{schema}.{table_name}")
)
