# %%
catalog = 'operations'
schema = 'finance_staging'
table_name = 'fact_staging_cash_flow_tbl'

# %%
with open("sql/.sql", "r") as file:
    qry = file.read()
(
    spark.sql(qry)
    .write
    .format("delta")
    .mode("overwrite")
    .option("overwriteSchema", "true")
    .saveAsTable(f"{catalog}.{schema}.{table_name}")
)
